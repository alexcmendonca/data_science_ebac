# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
# Criando dataframe com uma base de dados em .csv
df_sinasc = pd.read_csv('sinasc_RO_2019.csv', sep=',')

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
# Consultando o tamanho do df com o número de linhas e colunas
df_sinasc.shape
# Out:
# (27028, 69)

# %%
# Verificando os nomes das colunas do df
df_sinasc.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %%
df_sinasc['IDADEMAE']
# Out:
# 0        19
# 1        29
# 2        37
# 3        30
# 4        30
#          ..
# 27023    32
# 27024    19
# 27025    24
# 27026    21
# 27027    18
# Name: IDADEMAE, Length: 27028, dtype: int64

# %%
df_sinasc['IDADEMAE'].describe()
# Out:
# count    27028.000000
# mean        26.093718
# std          6.387094
# min         11.000000
# 25%         21.000000
# 50%         26.000000
# 75%         31.000000
# max         53.000000
# Name: IDADEMAE, dtype: float64

# %%
df_sinasc[['IDADEMAE']].boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(data=df_sinasc['IDADEMAE'])
# Out:
# <Axes: >

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
df_sinasc['PESO']
# Out:
# 0        3685
# 1        3055
# 2        3460
# 3        2982
# 4        3310
#          ...
# 27023    2110
# 27024    3310
# 27025    3065
# 27026    2352
# 27027    4240
# Name: PESO, Length: 27028, dtype: int64

# %%
df_sinasc['PESO'].describe()
# Out:
# count    27028.000000
# mean      3243.190654
# std        544.754096
# min        258.000000
# 25%       2965.000000
# 50%       3270.000000
# 75%       3575.000000
# max       5985.000000
# Name: PESO, dtype: float64

# %%
df_sinasc[['PESO']].boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(data=df_sinasc['PESO'])
# Out:
# <Axes: >

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
df_sinasc['IDADEMAE'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# %%
ax1.hist((df_sinasc['IDADEMAE']), bins = 20)
# Out:
# (array([  35.,  517., 1545., 2461., 2902., 2928., 3087., 2893., 2537.,
#         2252., 2728., 1366.,  902.,  533.,  241.,   79.,   13.,    5.,
#            0.,    4.]),
#  array([11. , 13.1, 15.2, 17.3, 19.4, 21.5, 23.6, 25.7, 27.8, 29.9, 32. ,
#         34.1, 36.2, 38.3, 40.4, 42.5, 44.6, 46.7, 48.8, 50.9, 53. ]),
#  <BarContainer object of 20 artists>)

# %%
ax2.boxplot(df_sinasc['IDADEMAE'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20bcbe9b250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20bcc34e5d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20bcb255d50>],
#  'medians': [<matplotlib.lines.Line2D at 0x20bcca11710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20bcc343650>],
#  'means': []}

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
df_sinasc['PESO'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(data = df_sinasc['PESO']
            ,alpha = .25
            ,bins = 20
            ,element = 'step'
            ,kde = True
                             )
# Out:
# <img src="data:image/png;base64,..." width="499.55555555555554">
