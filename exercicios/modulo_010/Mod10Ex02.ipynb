# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Fixing random state for reproducibility
np.random.seed(2360873)

df = pd.read_csv('previsao_de_renda.csv')
df.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
# Descisão tomada para excluir linhas NaN dentro do dataframe
df.dropna(subset=['tempo_emprego'], inplace=True)
df
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %%
# Excluindo variáveis desnecessárias para análise
df.drop(columns=['Unnamed: 0', 'index', 'mau'], inplace=True)
df.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    renda
# 0       3.575342                    3.0  3369.24
# ...

# %%
# Plotando o perfil das médias de posse de imóvel em relação à renda por meio de um gráfico de pontos
ax = sns.pointplot(x='posse_de_imovel', y='renda',
                  data=df, dodge=True, errorbar=('ci', 90))

# %%
# Plotando gráfico de perfis das médias posse de imóvel e renda, determinando a cor dos pontos com base
# na coluna 'posse_veículo'
ax_1 = sns.pointplot(x='posse_de_imovel', y='renda', hue='posse_de_veiculo',
                  data=df, dodge=True)

# %%
ax_2 = sns.pointplot(x='posse_de_veiculo', y='renda',
                  data=df, dodge=True)

# %%
ax_3 = sns.pointplot(x='posse_de_veiculo', y='renda', hue='posse_de_imovel',
                  data=df, dodge=True)

# %% [markdown]
# # Examinando as variáveis com o gráfico de análise de perfis das médias, é possível identificar que a variável 'posse_de_veiculo' destaca-se como um preditor mais robusto da renda, observando uma correlação positiva entre a posse de veículo e a renda, indicando que aqueles que possuem veículo tendem a apresentar renda mais elevada.
